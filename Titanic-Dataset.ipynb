# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakesh35-3789/Machine-Learning/blob/main/Titanic-Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load your uploaded Titanic dataset
df = pd.read_csv('Titanic-Dataset.csv')

# --- STEP 2: Understand the Data ---
print("--- 1. FIRST 5 ROWS ---")
display(df.head())

print("\n--- 2. DATA SHAPE (Rows, Columns) ---")
print(df.shape)

print("\n--- 3. DATA INFO ---")
df.info()

print("\n--- 4. SUMMARY STATISTICS ---")
display(df.describe())

# --- STEP 3: Clean the Data ---
# Drop exact duplicate rows
df = df.drop_duplicates()

# Fill missing numerical values (like Age) with the average
df = df.fillna(df.mean(numeric_only=True))

# --- STEP 4: Exploratory Data Analysis (EDA) ---
print("\n--- 5. VISUALIZING DATA PATTERNS ---")
df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()
# Out:
# --- 1. FIRST 5 ROWS ---
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...
